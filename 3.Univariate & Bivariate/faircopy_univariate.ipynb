# %%
from SaaS_Sales_Univariate import Univariate

# %%
import pandas as pd

dataset = pd.read_csv(
    r"D:\python\Machine Learning and Data Science Capstone Project\2.Data preprocessing\cleaned_saas_sales.csv"
)

# %%
freq_result=Univariate.freq_table(dataset)

# %%
freq_result
# Out:
# {'Country':                              Unique_Values  Frequency  Relative Frequency  \
#  Country
#  United States                United States       2001            0.200220
#  United Kingdom              United Kingdom       1141            0.114169
#  Japan                                Japan        985            0.098559
#  France                              France        587            0.058735
#  Canada                              Canada        506            0.050630
#  Australia                        Australia        492            0.049230
#  Mexico                              Mexico        469            0.046928
#  Germany                            Germany        383            0.038323
#  Brazil                              Brazil        255            0.025515
#  Sweden                              Sweden        249            0.024915
#  Chile                                Chile        224            0.022413
# ...

# %%
desc_result=Univariate.descriptive_statistics(dataset)

# %%
desc_result
# Out:
#                                                                 Sales  \
# Mean                                                       229.858001
# Median                                                          54.49
# Mode                                                            12.96
# Q1:25%                                                          17.28
# Q2:50%                                                          54.49
# Q3:75%                                                         209.94
# IQR                                                            192.66
# 1.5 Rule                                                       288.99
# Lower Limit                                                   -271.71
# Upper Limit                                                    498.93
# Outlier Count                                                    1167
# Standard Deviation                                         623.245101
# ...

# %%
plot_result=Univariate.plots(dataset)
